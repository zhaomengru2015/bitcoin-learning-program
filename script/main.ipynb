# %% [markdown]
# ## Script
#
# 如果字节的值是0x01~0x4b（n）字节，则读取接下来的n字节数据
#
# ### 常用的操作码
# • 0x00 - OP_0
# • 0x51 - OP_1
# • 0x60 - OP_16
# • 0x76 - OP_DUP
# • 0x93 - OP_ADD
# • 0xa9 - OP_HASH160
# • 0xac - OP_CHECKSIG
# opcode查找：https://en.bitcoin.it/wiki/Script
#
# ### Standard Scripts
# 当script执行完成的时候，stack上只有一个非0的元素，说明这是一个合法的script。
# #### 1. p2pk
# script_pub_key
#
#  ![image.png](attachment:image.png)
#
# script_sig
#
# ![image-2.png](attachment:image-2.png)
#
# stack
#
#  ![image-3.png](attachment:image-3.png)
#
#
#
# 2. p2pkh
#
# 优点：更短的地址
#
# ![image-4.png](attachment:image-4.png)
#
# 3. p2sh
# 4. p2wpkh
# 5. p2wsh

# %%
from script import Script
z = 0x7c076ff316692a3d7eb3c3bb0f8b1488cf72e1afcd929e29307032997a838a3d
# SEC format of pubkey
sec = bytes.fromhex('04887387e452b8eacc4acfde10d9aaf7f6d9a0f975aabb10d006e4da568744d06c61de6d95231cd89026e286df3b6ae4a894a3378e393e93a0f45b666329a0ae34')
# DER format of Signature
sig = bytes.fromhex('3045022000eff69ef2b1bd93a66ed5219add4fb51e11a840f404876325a1e8ffe0529a2c022100c7207fee197d27c618aea621406f6bf5ef6fca38681d82b2f06fddbdce6feab601')

script_pub_key=Script([sec,0xac])
script_sig=Script([sig])
combined_script=script_sig+script_pub_key
print(combined_script.cmds)
print(combined_script.evaluate(z))
# Out:
# [b"0E\x02 \x00\xef\xf6\x9e\xf2\xb1\xbd\x93\xa6n\xd5!\x9a\xddO\xb5\x1e\x11\xa8@\xf4\x04\x87c%\xa1\xe8\xff\xe0R\x9a,\x02!\x00\xc7 \x7f\xee\x19}'\xc6\x18\xae\xa6!@ok\xf5\xefo\xca8h\x1d\x82\xb2\xf0o\xdd\xbd\xceo\xea\xb6\x01", b'\x04\x88s\x87\xe4R\xb8\xea\xccJ\xcf\xde\x10\xd9\xaa\xf7\xf6\xd9\xa0\xf9u\xaa\xbb\x10\xd0\x06\xe4\xdaV\x87D\xd0la\xdem\x95#\x1c\xd8\x90&\xe2\x86\xdf;j\xe4\xa8\x94\xa37\x8e9>\x93\xa0\xf4[fc)\xa0\xae4', 172]
# evaluate command cmd 172, type(cmd) <class 'int'>, operation <function op_checksig at 0x109291790> stack [b"0E\x02 \x00\xef\xf6\x9e\xf2\xb1\xbd\x93\xa6n\xd5!\x9a\xddO\xb5\x1e\x11\xa8@\xf4\x04\x87c%\xa1\xe8\xff\xe0R\x9a,\x02!\x00\xc7 \x7f\xee\x19}'\xc6\x18\xae\xa6!@ok\xf5\xefo\xca8h\x1d\x82\xb2\xf0o\xdd\xbd\xceo\xea\xb6\x01", b'\x04\x88s\x87\xe4R\xb8\xea\xccJ\xcf\xde\x10\xd9\xaa\xf7\xf6\xd9\xa0\xf9u\xaa\xbb\x10\xd0\x06\xe4\xdaV\x87D\xd0la\xdem\x95#\x1c\xd8\x90&\xe2\x86\xdf;j\xe4\xa8\x94\xa37\x8e9>\x93\xa0\xf4[fc)\xa0\xae4']
#
#
# ...

# %%
from script import Script
z=b'hello'
sec=bytes.fromhex('')
script_sig=Script(['0x3045022100ed81ff192e75a3fd2304004dcadb746fa5e24c5031ccfcf21320b0277457c98f02207a986d955c6e0cb35d446a89d3f56100f4d7f67801c31967743a9c8e10615bed01','0x0349fc4e631e3624a545de3f89f5d8684c7b8138bd94bdd531d2e213bf016b278a'])
script_pub_key=Script([118,169,'0xa802fc56c704ce87c42d7c92eb75e7896bdc41ae',136,172])
